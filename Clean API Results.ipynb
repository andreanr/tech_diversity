# %%
import json
import pandas as pd
import numpy as np
from urllib.request import urlopen

# %%
def clean_name(s):
    return s.lower().replace(' ', '%20')

def gen_api_call(firstname, middlename, surname, country):
    call = '&split={}'.format(clean_name(firstname))
    if middlename:
        call = call + '%20{}'.format(clean_name(middlename))
    if surname:
        call = call + '%20{}'.format(clean_name(surname))
    if country:
        call = call + '&country={}'.format(country)
    return call

def call_api(call):
    call = URL + call
    response = urlopen(call)
    decoded = response.read().decode('utf-8')
    data = json.loads(decoded)
    return data

# %%
import yaml
def check_error(results):
    res = yaml.load(results)
    try:
        return res['errno']
    except:
        None
        
def get_gender(results):
    res = yaml.load(results)
    try:
        return res['gender']
    except:
        return None
    
def get_accuracy(results):
    res = yaml.load(results)
    try:
        return res['accuracy']
    except:
        return None

# %%
df = pd.read_csv('data/arxiv_first_ro_gender2_result.csv')

# %%
df.head()
# Out:
#            id                  name   Ofirstnam  Omidnam  Osurname  \
# 0          id                  name   Ofirstnam  Omidnam  Osurname
# 1  arxiv_ro_2  Alexander Yu. Vlasov   ALEXANDER      YU.    VLASOV
# 2  arxiv_ro_3       Andreas Siebert     ANDREAS      NaN   SIEBERT
# 3  arxiv_ro_4      Stephen L. Adler     STEPHEN      NaN     ADLER
# 4  arxiv_ro_5       Soumyadeep Paul  SOUMYADEEP      NaN      PAUL
#
#                         call  \
# 0  &name=ofirstnam%20omidnam
# 1      &name=alexander%20yu.
# 2              &name=andreas
# 3              &name=stephen
# 4           &name=soumyadeep
#
#                                              results
# 0  {'name': 'ofirstnam omidnam', 'name_sanitized'...
# 1  {'name': 'alexander yu.', 'name_sanitized': 'A...
# 2  {'name': 'andreas', 'name_sanitized': 'Andreas...
# 3  {'name': 'stephen', 'name_sanitized': 'Stephen...
# 4  {'name': 'soumyadeep', 'name_sanitized': 'Soum...

# %%
df = df.drop_duplicates()

# %%
df['results'].iloc[1]
# Out:
# "{'name': 'alexander yu.', 'name_sanitized': 'Alexander', 'country': '', 'gender': 'male', 'samples': 56237, 'accuracy': 99, 'duration': '24ms', 'credits_used': 1}"

# %%
df['gender'] = df['results'].map(get_gender)
df['accuracy'] = df['results'].map(get_accuracy)

# %%
df['gender'].value_counts(dropna=False)
# Out:
# male       39950
# female      7826
# unknown     1355
# NaN            1
# Name: gender, dtype: int64

# %%
df.head(10)
# Out:
#             id                  name   Ofirstnam  Omidnam  Osurname  \
# 0           id                  name   Ofirstnam  Omidnam  Osurname
# 1   arxiv_ro_2  Alexander Yu. Vlasov   ALEXANDER      YU.    VLASOV
# 2   arxiv_ro_3       Andreas Siebert     ANDREAS      NaN   SIEBERT
# 3   arxiv_ro_4      Stephen L. Adler     STEPHEN      NaN     ADLER
# 4   arxiv_ro_5       Soumyadeep Paul  SOUMYADEEP      NaN      PAUL
# 5   arxiv_ro_6      Sudipta N. Sinha     SUDIPTA      NaN     SINHA
# 6   arxiv_ro_7     Amitabha Mukerjee    AMITABHA      NaN  MUKERJEE
# 7   arxiv_ro_8       Mireille Boutin    MIREILLE      NaN    BOUTIN
# 8   arxiv_ro_9           Kagan Tumer       KAGAN      NaN     TUMER
# 9  arxiv_ro_10         Joydeep Ghosh     JOYDEEP      NaN     GHOSH
#
#                         call  \
# 0  &name=ofirstnam%20omidnam
# 1      &name=alexander%20yu.
# 2              &name=andreas
# 3              &name=stephen
# 4           &name=soumyadeep
# 5              &name=sudipta
# 6             &name=amitabha
# 7             &name=mireille
# 8                &name=kagan
# 9              &name=joydeep
#
#                                              results   gender  accuracy
# 0  {'name': 'ofirstnam omidnam', 'name_sanitized'...  unknown       0.0
# 1  {'name': 'alexander yu.', 'name_sanitized': 'A...     male      99.0
# 2  {'name': 'andreas', 'name_sanitized': 'Andreas...     male      99.0
# 3  {'name': 'stephen', 'name_sanitized': 'Stephen...     male      99.0
# 4  {'name': 'soumyadeep', 'name_sanitized': 'Soum...     male     100.0
# 5  {'name': 'sudipta', 'name_sanitized': 'Sudipta...     male      82.0
# 6  {'name': 'amitabha', 'name_sanitized': 'Amitab...     male      97.0
# 7  {'name': 'mireille', 'name_sanitized': 'Mireil...   female      98.0
# 8  {'name': 'kagan', 'name_sanitized': 'Kagan', '...     male      95.0
# 9  {'name': 'joydeep', 'name_sanitized': 'Joydeep...     male     100.0

# %%
cols = ['id', 'name', 'Ofirstnam', 'Osurname', 'gender', 'accuracy']
df[cols].to_csv('data/api_results/gender_results/arxiv_first_ro_gender2.csv')

# %%
df.head()
# Out:
#              name  author_name  author_middle_name  author_surname  \
# 0            name  author_name  author_middle_name  author_surname
# 1   K. M. Lochner           K.                  M.         Lochner
# 2    D. M. Reeves           D.                  M.          Reeves
# 3  Y. Vorobeychik           Y.                None     Vorobeychik
# 4   M. P. Wellman           M.                  P.         Wellman
#
#                                              results   gender accuracy  \
# 0  {'last_name': 'Name', 'first_name': '', 'stric...  unknown        0
# 1  {'last_name': 'Lochner', 'first_name': 'K. M.'...     None       61
# 2  {'last_name': 'Reeves', 'first_name': 'D. M.',...     None       73
# 3  {'last_name': 'Y.', 'first_name': '', 'strict'...     None        0
# 4  {'last_name': 'Wellman', 'first_name': 'M. P.'...     None       73
#
#    len_name  len_middle_name
# 0      11.0             18.0
# 1       1.0              1.0
# 2       1.0              1.0
# 3       1.0              NaN
# 4       1.0              1.0

# %% [markdown]
# ## Ethnicity

# %%
df = pd.read_csv('data/arxiv_first_sy_ethnic_result.csv')
df = df.drop_duplicates()

# %%
yaml.load(df['results'].iloc[0]).keys()
# Out:
# dict_keys(['2PRACE', 'Hispanic', 'API', 'Black', 'AIAN', 'White'])

# %%
import yaml
KEYS = ['2PRACE', 'Hispanic', 'API', 'Black', 'AIAN', 'White']
new_KEYS =  ['NamePrism_{}'.format(x) for x in KEYS]
def get_ethnicity(results):
    try:
        res = yaml.load(results)
        return res['2PRACE'], res['Hispanic'], res['API'], res['Black'], res['AIAN'], res['White']
    except:
        return None, None, None, None, None, None
    
def get_max_ethnicity(row):
    ethnicities = []
    
    for k in new_KEYS:
        if isinstance(row[k], float):
            ethnicities.append(row[k])
        else:
            return None
        
    return KEYS[np.argmax(ethnicities)]

# %%
for k in new_KEYS:
    df[k] = None

df[new_KEYS[0]], df[new_KEYS[1]], df[new_KEYS[2]], df[new_KEYS[3]], df[new_KEYS[4]], df[new_KEYS[5]] = zip(*df['results'].map(get_ethnicity))

# %%
df['NamePrism_ethnicity'] = df.apply(lambda x: get_max_ethnicity(x), axis=1)

# %%
df.head()
# Out:
#            id               name  Ofirstnam  Omidnam    Osurname  \
# 0          id               name  Ofirstnam  Omidnam    Osurname
# 1  arxiv_sy_0   Sandro A. Coelho     SANDRO      NaN      COELHO
# 2  arxiv_sy_1   Diego Moussallem      DIEGO      NaN  MOUSSALLEM
# 3  arxiv_sy_2  Gustavo C. Publio    GUSTAVO      NaN      PUBLIO
# 4  arxiv_sy_3      Diego Esteves      DIEGO      NaN     ESTEVES
#
#                                              results NamePrism_2PRACE  \
# 0  {'2PRACE': 1.5983701819861723e-06, 'Hispanic':...      1.59837e-06
# 1  {'2PRACE': 1.0575078031311818e-06, 'Hispanic':...      1.05751e-06
# 2  {'2PRACE': 0.0002782917126488064, 'Hispanic': ...      0.000278292
# 3  {'2PRACE': 0.00022398947128404972, 'Hispanic':...      0.000223989
# 4  {'2PRACE': 0.0005175848450145907, 'Hispanic': ...      0.000517585
#
#   NamePrism_Hispanic NamePrism_API NamePrism_Black NamePrism_AIAN  \
# 0          0.0372441     0.0560092       0.0373316    6.83087e-06
# 1          0.0623419    0.00415719      0.00011892    1.64203e-07
# 2           0.507371     0.0103683      0.00820891     0.00090819
# 3           0.854625    0.00644003      0.00260238    0.000682087
# 4           0.838679     0.0194822     0.000954493    0.000505777
#
#   NamePrism_White NamePrism_ethnicity
# 0        0.869407               White
# 1        0.933381               White
# 2        0.472865            Hispanic
# 3        0.135426            Hispanic
# 4        0.139861            Hispanic

# %%
cols = ['id', 'name', 'NamePrism_ethnicity'] + new_KEYS

# %%
df[cols].to_csv('data/api_results/ethnicity_results/arxiv_first_sy_ethnic_result.csv')
